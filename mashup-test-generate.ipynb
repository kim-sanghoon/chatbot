# %%
from mashup import *

import matplotlib.pyplot as plt
import networkx as nx

# %%
# Loading dump interaction file
m = Mashup(fname='dump/greetings-kcc.bin')
# Out:
# {'position': ['if'], 'pos_action': 'come', 'object': ['light', 'air conditioner'], 'number': '', 'pos_object': 'self', 'time': '', 'params': ['home'], 'any': '', 'action': 'enable'}
# {'position': ['then'], 'pos_action': '', 'object': ['shade'], 'number': '', 'pos_object': '', 'time': '', 'params': [], 'any': '', 'action': 'decrease'}
# {'position': ['if'], 'pos_action': '', 'object': ['audio'], 'number': '', 'pos_object': 'success', 'time': '', 'params': [], 'any': '', 'action': 'enable'}
# {'position': ['if'], 'pos_action': '', 'object': ['self'], 'number': '', 'pos_object': 'fail', 'time': '', 'params': [], 'any': '', 'action': 'remind'}

# %%
plt.figure(figsize=(5,5))
nx.draw_networkx(m.graph, node_color='skyblue', font_size=10)
plt.axis('off')
plt.show()
