# %%
from mashup import *

import matplotlib.pyplot as plt
import networkx as nx

# %%
# Loading dump interaction file
m = Mashup(fname='dump/1589965148.bin')
n = Mashup(fname='dump/1589965148.bin')
# Out:
# {'time': '', 'object': ['light'], 'params': ['home'], 'position': ['if'], 'number': '', 'action': 'enable', 'pos_object': 'self', 'pos_action': 'come'}
# {'time': '', 'object': ['air conditioner'], 'params': [], 'position': [], 'pos_object': '', 'action': 'enable', 'number': '', 'pos_action': ''}
# {'time': '', 'object': ['light'], 'params': ['home'], 'position': ['if'], 'number': '', 'action': 'enable', 'pos_object': 'self', 'pos_action': 'come'}
# {'time': '', 'object': ['air conditioner'], 'params': [], 'position': [], 'pos_object': '', 'action': 'enable', 'number': '', 'pos_action': ''}

# %%
m.merge(n)

nx.draw_networkx(m.graph)
plt.show()
